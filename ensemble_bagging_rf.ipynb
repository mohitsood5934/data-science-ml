# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X, y = make_classification(n_features = 5, n_redundant = 0, n_informative = 5, n_clusters_per_class = 1)
# print(X, "X")
# print(y, "y")
df = pd.DataFrame(X, columns=['col1','col2','col3','col4','col5'])
df['Target'] = y
print(df)
print('Length of dataframe', len(df))
print("----->*****<-----")
print(df.shape)
# Out:
#         col1      col2      col3      col4      col5  Target
# 0  -1.952721  0.092601  0.068037  0.021963  2.303519       1
# 1  -1.312682 -1.200990  0.906421  0.534066 -0.174003       0
# 2   0.832828 -1.510233 -1.208026  1.221833 -0.916359       1
# 3  -5.101621  0.664276  1.506723  2.816745 -3.357174       0
# 4   2.662794 -2.516069 -0.511271  1.648848 -1.131713       1
# ..       ...       ...       ...       ...       ...     ...
# 95  3.073594 -1.497487 -1.508188  1.681146 -4.260342       1
# 96  0.477388 -1.275905 -0.131013  0.946339 -0.888077       0
# 97 -0.262563 -0.354186 -1.474084  0.682467 -0.653592       1
# 98 -2.864815 -0.320835 -1.153667  1.533957  2.343405       1
# 99  0.346718 -1.034745 -0.822396  1.012348 -0.183282       1
#
# [100 rows x 6 columns]
# Length of dataframe 100
# ----->*****<-----
# (100, 6)

# %%
bag = BaggingClassifier(max_features = 2)
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
# Out:
# [Text(0.4407894736842105, 0.9444444444444444, 'x[0] <= -0.567\ngini = 0.495\nsamples = 62\nvalue = [55.0, 45.0]'),
#  Text(0.15789473684210525, 0.8333333333333334, 'x[1] <= 1.411\ngini = 0.278\nsamples = 27\nvalue = [35, 7]'),
#  Text(0.29934210526315785, 0.8888888888888888, 'True  '),
#  Text(0.10526315789473684, 0.7222222222222222, 'x[1] <= 0.158\ngini = 0.102\nsamples = 25\nvalue = [35, 2]'),
#  Text(0.05263157894736842, 0.6111111111111112, 'gini = 0.0\nsamples = 19\nvalue = [29, 0]'),
#  Text(0.15789473684210525, 0.6111111111111112, 'x[1] <= 0.296\ngini = 0.375\nsamples = 6\nvalue = [6, 2]'),
#  Text(0.10526315789473684, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21052631578947367, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(0.21052631578947367, 0.7222222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.7236842105263158, 0.8333333333333334, 'x[1] <= 0.097\ngini = 0.452\nsamples = 35\nvalue = [20, 38]'),
#  Text(0.5822368421052632, 0.8888888888888888, '  False'),
#  Text(0.5526315789473685, 0.7222222222222222, 'x[0] <= 0.566\ngini = 0.415\nsamples = 30\nvalue = [15, 36]'),
#  Text(0.3684210526315789, 0.6111111111111112, 'x[1] <= -0.878\ngini = 0.5\nsamples = 11\nvalue = [9, 9]'),
#  Text(0.3157894736842105, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(0.42105263157894735, 0.5, 'x[0] <= 0.21\ngini = 0.298\nsamples = 7\nvalue = [2, 9]'),
#  Text(0.3684210526315789, 0.3888888888888889, 'x[0] <= 0.149\ngini = 0.444\nsamples = 3\nvalue = [2, 4]'),
#  Text(0.3157894736842105, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.42105263157894735, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.47368421052631576, 0.3888888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 5]'),
#  Text(0.7368421052631579, 0.6111111111111112, 'x[1] <= -2.122\ngini = 0.298\nsamples = 19\nvalue = [6, 27]'),
#  Text(0.6842105263157895, 0.5, 'x[1] <= -2.236\ngini = 0.457\nsamples = 9\nvalue = [6, 11]'),
#  Text(0.631578947368421, 0.3888888888888889, 'x[0] <= 1.242\ngini = 0.337\nsamples = 8\nvalue = [3, 11]'),
#  Text(0.5263157894736842, 0.2777777777777778, 'x[1] <= -2.503\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(0.47368421052631576, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.5789473684210527, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.7368421052631579, 0.2777777777777778, 'x[1] <= -2.296\ngini = 0.18\nsamples = 6\nvalue = [1, 9]'),
#  Text(0.6842105263157895, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 6]'),
#  Text(0.7894736842105263, 0.16666666666666666, 'x[0] <= 1.891\ngini = 0.375\nsamples = 2\nvalue = [1, 3]'),
#  Text(0.7368421052631579, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(0.8421052631578947, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7368421052631579, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(0.7894736842105263, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 16]'),
#  Text(0.8947368421052632, 0.7222222222222222, 'x[0] <= 0.999\ngini = 0.408\nsamples = 5\nvalue = [5, 2]'),
#  Text(0.8421052631578947, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9473684210526315, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]')]

# %%
rf = RandomForestClassifier(max_features = 2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
# Out:
# [Text(0.4407894736842105, 0.9444444444444444, 'x[0] <= -0.567\ngini = 0.495\nsamples = 62\nvalue = [55.0, 45.0]'),
#  Text(0.15789473684210525, 0.8333333333333334, 'x[1] <= 1.411\ngini = 0.278\nsamples = 27\nvalue = [35, 7]'),
#  Text(0.29934210526315785, 0.8888888888888888, 'True  '),
#  Text(0.10526315789473684, 0.7222222222222222, 'x[1] <= 0.158\ngini = 0.102\nsamples = 25\nvalue = [35, 2]'),
#  Text(0.05263157894736842, 0.6111111111111112, 'gini = 0.0\nsamples = 19\nvalue = [29, 0]'),
#  Text(0.15789473684210525, 0.6111111111111112, 'x[1] <= 0.296\ngini = 0.375\nsamples = 6\nvalue = [6, 2]'),
#  Text(0.10526315789473684, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21052631578947367, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(0.21052631578947367, 0.7222222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.7236842105263158, 0.8333333333333334, 'x[1] <= 0.097\ngini = 0.452\nsamples = 35\nvalue = [20, 38]'),
#  Text(0.5822368421052632, 0.8888888888888888, '  False'),
#  Text(0.5526315789473685, 0.7222222222222222, 'x[0] <= 0.566\ngini = 0.415\nsamples = 30\nvalue = [15, 36]'),
#  Text(0.3684210526315789, 0.6111111111111112, 'x[1] <= -0.878\ngini = 0.5\nsamples = 11\nvalue = [9, 9]'),
#  Text(0.3157894736842105, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(0.42105263157894735, 0.5, 'x[0] <= 0.21\ngini = 0.298\nsamples = 7\nvalue = [2, 9]'),
#  Text(0.3684210526315789, 0.3888888888888889, 'x[0] <= 0.149\ngini = 0.444\nsamples = 3\nvalue = [2, 4]'),
#  Text(0.3157894736842105, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.42105263157894735, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.47368421052631576, 0.3888888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 5]'),
#  Text(0.7368421052631579, 0.6111111111111112, 'x[1] <= -2.122\ngini = 0.298\nsamples = 19\nvalue = [6, 27]'),
#  Text(0.6842105263157895, 0.5, 'x[1] <= -2.236\ngini = 0.457\nsamples = 9\nvalue = [6, 11]'),
#  Text(0.631578947368421, 0.3888888888888889, 'x[0] <= 1.242\ngini = 0.337\nsamples = 8\nvalue = [3, 11]'),
#  Text(0.5263157894736842, 0.2777777777777778, 'x[1] <= -2.503\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(0.47368421052631576, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.5789473684210527, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.7368421052631579, 0.2777777777777778, 'x[1] <= -2.296\ngini = 0.18\nsamples = 6\nvalue = [1, 9]'),
#  Text(0.6842105263157895, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 6]'),
#  Text(0.7894736842105263, 0.16666666666666666, 'x[0] <= 1.891\ngini = 0.375\nsamples = 2\nvalue = [1, 3]'),
#  Text(0.7368421052631579, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(0.8421052631578947, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7368421052631579, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(0.7894736842105263, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 16]'),
#  Text(0.8947368421052632, 0.7222222222222222, 'x[0] <= 0.999\ngini = 0.408\nsamples = 5\nvalue = [5, 2]'),
#  Text(0.8421052631578947, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9473684210526315, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]')]
